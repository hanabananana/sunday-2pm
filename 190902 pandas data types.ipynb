# %% [markdown]
# # article from: https://pbpython.com/pandas_dtypes.html
# # article by: Chris Moffitt

# %% [markdown]
# ## python data types

# %%
type("hello")
# Out:
# str

# %%
type(12)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
 1 + 2
# Out:
# 3

# %%
"jupyter" + "notebook"
# Out:
# 'jupyternotebook'

# %% [markdown]
# ## pandas data types

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(".\sales_data_types.csv")

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0          10002.0  Quest Industries  $125,000.00    $162500.00
# 1         552278.0    Smith Plumbing  $920,000.00  $101,2000.00
# 2          23477.0   ACME Industrial   $50,000.00     $62500.00
# 3          24900.0        Brekke LTD  $350,000.00    $490000.00
# 4         651029.0         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df.dtypes
# Out:
# Customer Number    float64
# Customer Name       object
# 2016                object
# 2017                object
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## why do we care for data types ?

# %% [markdown]
# ## why type conversion?

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0          10002.0  Quest Industries  $125,000.00    $162500.00
# 1         552278.0    Smith Plumbing  $920,000.00  $101,2000.00
# 2          23477.0   ACME Industrial   $50,000.00     $62500.00
# 3          24900.0        Brekke LTD  $350,000.00    $490000.00
# 4         651029.0         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df['2016'] +df['2017']
# Out:
# 0      $125,000.00$162500.00
# 1    $920,000.00$101,2000.00
# 2        $50,000.00$62500.00
# 3      $350,000.00$490000.00
# 4        $15,000.00$12750.00
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## option 1. astype()

# %% [markdown]
# ## Customer Number data type : float64 -> int64

# %%
df['Customer Number'].dtype
# Out:
# dtype('float64')

# %%
df['Customer Number'].astype('int')
# Out:
# 0     10002
# 1    552278
# 2     23477
# 3     24900
# 4    651029
# Name: Customer Number, dtype: int32

# %%
df['Customer Number'] = df['Customer Number'].astype('int')
df.dtypes
# Out:
# Customer Number     int32
# Customer Name      object
# 2016               object
# 2017               object
# Percent Growth     object
# Jan Units          object
# Month               int64
# Day                 int64
# Year                int64
# Active             object
# dtype: object

# %% [markdown]
# ## astype() does not work every time!

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df.dtypes
# Out:
# Customer Number     int32
# Customer Name      object
# 2016               object
# 2017               object
# Percent Growth     object
# Jan Units          object
# Month               int64
# Day                 int64
# Year                int64
# Active             object
# dtype: object

# %% [markdown]
# ## 2016 data type: object -> float64

# %%
df['2016'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-999869d577b0> in <module>
# ----> 1 df['2016'].astype('float')
#
# ~\Anaconda3\envs\virEnvFolium\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\envs\virEnvFolium\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df.dtypes
# Out:
# Customer Number     int32
# Customer Name      object
# 2016               object
# 2017               object
# Percent Growth     object
# Jan Units          object
# Month               int64
# Day                 int64
# Year                int64
# Active             object
# dtype: object

# %%
df['Jan Units'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-31333711e4a4> in <module>
# ----> 1 df['Jan Units'].astype('int')
#
# ~\Anaconda3\envs\virEnvFolium\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\envs\virEnvFolium\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df.dtypes
# Out:
# Customer Number     int32
# Customer Name      object
# 2016               object
# 2017               object
# Percent Growth     object
# Jan Units          object
# Month               int64
# Day                 int64
# Year                int64
# Active             object
# dtype: object

# %%
df['Active'].astype('bool')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Active, dtype: bool

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## option 2. custom conversion functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df.dtypes
# Out:
# Customer Number     int32
# Customer Name      object
# 2016               object
# 2017               object
# Percent Growth     object
# Jan Units          object
# Month               int64
# Day                 int64
# Year                int64
# Active             object
# dtype: object

# %% [markdown]
# ## 2016, 2017 data type : object -> float

# %%
def convert_currency(val):
    '''
        string value -> float value
        remove $
        remove ,
    '''
    new_val = val.replace('$', '').replace(',','')
    return float(new_val)

# %%
df['2016'].apply(convert_currency)
# Out:
# 0    125000.0
# 1    920000.0
# 2     50000.0
# 3    350000.0
# 4     15000.0
# Name: 2016, dtype: float64

# %%
df
# Out:
#    Customer Number     Customer Name      2016          2017 Percent Growth  \
# 0            10002  Quest Industries  125000.0    $162500.00         30.00%
# 1           552278    Smith Plumbing  920000.0  $101,2000.00         10.00%
# 2            23477   ACME Industrial   50000.0     $62500.00         25.00%
# 3            24900        Brekke LTD  350000.0    $490000.00          4.00%
# 4           651029         Harbor Co   15000.0     $12750.00        -15.00%
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y
# 2       125      3   29  2016      Y
# 3        75     10   27  2015      Y
# 4    Closed      2    2  2014      N

# %%
df.dtypes
# Out:
# Customer Number     int32
# Customer Name      object
# 2016               object
# 2017               object
# Percent Growth     object
# Jan Units          object
# Month               int64
# Day                 int64
# Year                int64
# Active             object
# dtype: object

# %%
df['2016'] = df['2016'].apply(convert_currency)

# %%
df.dtypes
# Out:
# Customer Number      int32
# Customer Name       object
# 2016               float64
# 2017                object
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
df['2017'] = df['2017'].apply(convert_currency)

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017 Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0         30.00%
# 1           552278    Smith Plumbing  920000.0  1012000.0         10.00%
# 2            23477   ACME Industrial   50000.0    62500.0         25.00%
# 3            24900        Brekke LTD  350000.0   490000.0          4.00%
# 4           651029         Harbor Co   15000.0    12750.0        -15.00%
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y
# 2       125      3   29  2016      Y
# 3        75     10   27  2015      Y
# 4    Closed      2    2  2014      N

# %% [markdown]
# ## Percent Growth data type: object -> float

# %%
def convert_percent(val):
    '''
        object -> float
        remove %
        divide by 100 to make decimal
    '''
    new_val = val.replace('%', '')
    return float(new_val) / 100

df['Percent Growth'] = df['Percent Growth'].apply(convert_percent)

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y
# 2       125      3   29  2016      Y
# 3        75     10   27  2015      Y
# 4    Closed      2    2  2014      N

# %% [markdown]
# ## np.where() 의 활용

# %% [markdown]
# ## Active data type: object -> bool

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['Active'] = np.where(df['Active'] == 'Y', True, False)

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year  Active
# 0       500      1   10  2015    True
# 1       700      6   15  2014    True
# 2       125      3   29  2016    True
# 3        75     10   27  2015    True
# 4    Closed      2    2  2014   False

# %%
df.dtypes
# Out:
# Customer Number      int32
# Customer Name       object
# 2016               float64
# 2017               float64
# Percent Growth     float64
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active                bool
# dtype: object

# %% [markdown]
# ## option 3. pandas helper functions
# ## pd.to_numeric()
# ## pd.to_datetime()

# %%
df['Jan Units'] = pd.to_numeric(df['Jan Units'], errors='coerce')

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active
# 0      500.0      1   10  2015    True
# 1      700.0      6   15  2014    True
# 2      125.0      3   29  2016    True
# 3       75.0     10   27  2015    True
# 4        NaN      2    2  2014   False

# %%
df['year-month-date'] = pd.to_datetime(df[['Month', 'Day', 'Year']])

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active year-month-date
# 0      500.0      1   10  2015    True      2015-01-10
# 1      700.0      6   15  2014    True      2014-06-15
# 2      125.0      3   29  2016    True      2016-03-29
# 3       75.0     10   27  2015    True      2015-10-27
# 4        NaN      2    2  2014   False      2014-02-02

# %%
df.dtypes
# Out:
# Customer Number             int32
# Customer Name              object
# 2016                      float64
# 2017                      float64
# Percent Growth            float64
# Jan Units                 float64
# Month                       int64
# Day                         int64
# Year                        int64
# Active                       bool
# year-month-date    datetime64[ns]
# dtype: object
